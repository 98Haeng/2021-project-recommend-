# %%
# !pip install requests
# !pip install bs4

# %%
import pandas as pd
import numpy as np
from selenium import webdriver
import time
from bs4 import BeautifulSoup
import requests

# %%
from selenium.webdriver.common.keys import Keys

# %%
options=webdriver.ChromeOptions()
options.add_argument('user_agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.107 Safari/537.36')
options.add_experimental_option("excludeSwitches", ["enable-logging"])

basepath='C:/Users/이신행/OneDrive/바탕 화면/chromedriver_win32/'
browser=webdriver.Chrome(executable_path=basepath+'chromedriver.exe',options=options)

# %%
articletitle=[]
title='유아용품 온라인 시장'
url='https://www.google.com/'
browser.get(url)
element=browser.find_element_by_class_name('gLFyf.gsfi')
element.send_keys(title)
element.submit()
browser.implicitly_wait(1)

# 1페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()
    
# 2페이지   
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()   
    
# 3페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

# 4페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click() 

# 5페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()
    
# 6페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

# 7페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

# 8페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

# 9페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

# 10페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

# 11페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

# 12페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

# 13페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

# 14페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

# 15페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

# 16페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
# browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

# # 17페이지
# elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
# for e in range(len(elements)):
#     element=elements[e].text
#     articletitle.append(element)
    
# 더보기 버튼 누르기
browser.find_element_by_css_selector('#ofr > i > a').click()

# %%
# 초기화
articletitle=[]

# 1페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()
    
# 2페이지   
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()   
    
# 3페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

# 4페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click() 

# 5페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()
    
# 6페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

# 7페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

# 8페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

# 9페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

# 10페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

browser.implicitly_wait(3)
# 11페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

# 12페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

# 13페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

# 14페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

# 15페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

browser.implicitly_wait(3)
# 16페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

# 17페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
# browser.find_element_by_css_selector('#ofr > i > a').click()
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

# 18페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

# 19페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

# 20페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()
browser.implicitly_wait(3)
# 21페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

# 22페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

# 23페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

# 24페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

# 25페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()
browser.implicitly_wait(3)

# %%
# 26페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

# 27페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

# 28페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

# 29페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

# 30페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()
browser.implicitly_wait(3)
# 31페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

# 32페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

# 33페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

# 34페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

# 35페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

browser.implicitly_wait(3)
# 36페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()


# 37페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()


# 38페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()


# 39페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()


# 40페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()
browser.implicitly_wait(3)
# 41페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

# 42페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

# 43페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

# 44페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

# 45페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()
browser.implicitly_wait(3)
# 46페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

# 47페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

# 48페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

# 49페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

# 50페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()
browser.implicitly_wait(3)
# 51페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

# 52페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

# 53페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

# 54페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

# 55페이지
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()

print(articletitle)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-23-539207b54c22> in <module>
#      99     element=elements[e].text
#     100     articletitle.append(element)
# --> 101 browser.find_element_by_css_selector('#pnnext > span:nth-child(2)').click()
#     102
#     103
#
# C:\anaconda\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_css_selector(self, css_selector)
#     596             element = driver.find_element_by_css_selector('#foo')
#     597         """
# --> 598         return self.find_element(by=By.CSS_SELECTOR, value=css_selector)
#     599
#     600     def find_elements_by_css_selector(self, css_selector):
#
# C:\anaconda\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# ...

# %%
articletitle
# Out:
# ['4조 육아시장 어떻게 잡나, 육아맘 주 이용 채널 분석하기',
#  '위메프 "유아용품 온라인으로 대량 구매하는 소비자 늘어"',
#  '중국 영유아용품 시장 최신 트렌드 - Kotra 해외시장뉴스',
#  '美 유아용품 온라인쇼핑으로 성장세 지속 - 트렌드 - Kotra 해외 ...',
#  '美 유아용품 온라인쇼핑으로 성장세 지속 - Kotra 해외시장뉴스',
#  "中 영유아시장, '온라인'으로 통한다! - 트렌드 - KOTRA 해외시장 ...",
#  '일본 유아용품산업 - 국별 주요산업 - Kotra 해외시장뉴스',
#  '아이 1명도 안 낳는데…유아용품 산업은 왜 흔들리지 않을까',
#  '세계의 유아용품 온라인 소매 시장(2021-2025년) - 글로벌 ...',
#  '유아용품 온라인 시장 커진다 - 어패럴뉴스',
#  '코로나19 영향으로 미국 출생률 감소, 유아용품 업계 먹구름',
#  '에콰도르 유아용품 시장 트렌드 - 상품·산업 - Kotra 해외시장뉴스',
#  '美 유아용품 온라인쇼핑으로 성장세 지속 - 상품·산업 - Kotra ...',
#  '美 유아용품 온라인쇼핑으로 성장세 지속 - Kotra 해외시장뉴스',
#  '美 유아용품 온라인쇼핑으로 성장세 지속 - Kotra 해외시장뉴스',
#  '유아용품의 모든 것, 미국 2019 ABC Kids Expo 참관기 - Kotra ...',
#  '파라과이 유아용품 시장 동향 - 트렌드 - KOTRA 해외시장뉴스',
#  '점점 커지는 유아용품 시장…신세계 온라인 키즈 전문관 낸다',
#  "美 유아용품 시장, '스마트, 프리미엄' 강세-해외시장 뉴스",
#  '중국 영유아용품 시장 최신 트렌드 - 상품·산업 - KOTRA 해외 ...',
#  '美 유아용품 온라인쇼핑으로 성장세 지속 - Kotra 해외시장뉴스',
#  '말레이시아 유아용품 시장 트렌드 - KOTRA 해외시장뉴스',
#  '싱가포르 유아용품 시장 트렌드 - Kotra 해외시장뉴스',
# ...

# %%
articles=pd.DataFrame(articletitle)

# %%
articles
# Out:
#                                               0
# 0              4조 육아시장 어떻게 잡나, 육아맘 주 이용 채널 분석하기
# 1               위메프 "유아용품 온라인으로 대량 구매하는 소비자 늘어"
# 2             중국 영유아용품 시장 최신 트렌드 - Kotra 해외시장뉴스
# 3    美 유아용품 온라인쇼핑으로 성장세 지속 - 트렌드 - Kotra 해외 ...
# 4          美 유아용품 온라인쇼핑으로 성장세 지속 - Kotra 해외시장뉴스
# ..                                          ...
# 384       2020년 이커머스 트렌드 중간점검 : 코로나19 이후 위기와 기회
# 385      5년 후 세계 위기는 공평하게 다가온다 - Google 도서 검색결과
# 386                        스틸러 - Google 도서 검색결과
# 387                    마케팅의 정석 - Google 도서 검색결과
# 388           주식투자 - 유망종목 가이드 북: 주식투자 여기서만 해라!!
#
# [389 rows x 1 columns]

# %%
articles.to_excel('구글검색결과제목.xlsx',index=False)

# %%
# for i in range(5):    
#     elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
#     for e in range(len(elements)):
#         element=elements[e].text
#         articletitle.append(element)
        
#     but=browser.find_element_by_css_selector('#xjs > table > tbody > tr > td:nth-child({}) > a'.format(i+2))
#     but.click()

# %%
articles=[]
title='유아용품 온라인 시장'
url='https://www.google.com/'
browser.get(url)
element=browser.find_element_by_class_name('gLFyf.gsfi')
element.send_keys(title)
element.submit()
browser.implicitly_wait(3)
element=browser.find_element_by_css_selector('#rso > div:nth-child(1) > div > div > div.yuRUbf > a > h3')
element.click()
# element2=browser.find_element_by_css_selector('#post-14605 > div')
# elem2=element2.text
# print(elem)
# print(elem2)
soup=BeautifulSoup(browser.page_source,'html.parser')
div=soup.find('div',attrs={'class':'entry-content clearfix'})
# divs=div.find_all('div',atters={'class':'LC20lb.DKV0Md'})
for index,d in enumerate(div):
    try:
        element=browser.find_element_by_xpath('//*[@id="post-14605"]/div/p[%d]'%index).text
        articles.append(element)
    except:
        
# for index,d in enumerate(div):
#     element=browser.find_element_by_xpath('//*[@id="post-14605"]/div/p[{}]'.format(index)).text
#     articles.append(element)

# %%
articles
# Out:
# ['4조 육아시장 어떻게 잡나, 육아맘 주 이용 채널 분석하기',
#  '본 글은 36개월 이하의 자녀를 둔 엄마 500명, 아빠 200명을 대상으로 조사한 ‘육아 트렌드 리포트 2020’ 내용을 활용해 작성한 글입니다.',
#  '산업연구원이 지난 19년에 발표한 <국내 키즈콘텐츠시장의 현황과 시사점> 보고서에 따르면, 유아용품 시장은 2009년 1조 2,000억 원에서 2015년 약 2조 4,000억 원으로 두 배 가량 성장했으며, 2019년은 4조 원대로 성장했을 것이라 전망했습니다. 국내 출생아 수는 꾸준한 감소세인데 유아용품 시장이 빠르게 성장하는 특별한 이유가 있을까요?',
#  '기사에 따르면 출산율 하락이 오히려 육아시장 성장에 도움을 준다고 분석합니다. 가정 내 아이의 수가 줄어들면서 부모의 지원 쏠림 현상이 나타나고 있습니다. 예전에는 첫째 아이의 옷이나 유아용품을 둘째와 셋째가 물려받아서 쓰곤 했는데, 한 아이만 낳아 키우는 부모가 늘어나면서 더 좋고 더 비싼 프리미엄 유아용품을 사주려는 풍조 덕에 ‘골드키즈’ 시대가 열린 겁니다.',
#  '이에 극심한 저출산 시대인 지금, 육아시장 사로잡기에 대한 관심은 더욱 높아지고 있습니다. 이러한 시장 변화에 맞춰 오픈서베이는 육아 트렌드 리포트를 지난 17년 이후 새롭게 발행했습니다. 육아 트렌드 리포트 2020을 토대로 작성한 본 아티클을 통해 엄마들을 사로잡을 마케팅 전략에 대한 힌트를 얻을 수 있길 바랍니다.',
#  '먼저 엄마들이 자녀 양육 정보를 주로 얻는 채널을 살펴보니, 온라인 커뮤니티를 이용한다는 의견이 가장 많은 것으로 나타났습니다(71.2%). 지난 17년까지 가장 많은 비율을 차지하던 가족·친구 등 육아 선배를 꼽은 엄마들이 적지 않게 줄어든 탓이 큽니다(66.2%, -13.6%P). 이제는 육아 관련 정보도 온라인에서 더욱 많이 얻는 시대가 열린 겁니다.',
# ...

# %%
articles=[]
title='유아용품 온라인 시장'
url='https://www.google.com/'
browser.get(url)
element=browser.find_element_by_class_name('gLFyf.gsfi')
element.send_keys(title)
element.submit()
browser.implicitly_wait(3)
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
for c in elements:
    c.click()
# div=soup.find_all('h3',attrs={'class':'LC20lb.DKV0Md'})
# for index,data in enumerate(div):
#     data.click()
# element2=browser.find_element_by_css_selector('#post-14605 > div')
# elem2=element2.text
# print(elem)
# print(elem2)
    soup=BeautifulSoup(browser.page_source,'html.parser')
    div2=soup.find('div',attrs={'class':'entry-content clearfix'})
# divs=div.find_all('div',atters={'class':'LC20lb.DKV0Md'})
    for index,d in enumerate(div2):
        try:
            element=browser.find_element_by_xpath('//*[@id="post-14605"]/div/p[%d]'%index).text
            articles.append(element)
        except:
            pass
    browser.back()
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# <ipython-input-12-1bb7e4b5fff3> in <module>
#       9 elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
#      10 for c in elements:
# ---> 11     c.click()
#      12 # div=soup.find_all('h3',attrs={'class':'LC20lb.DKV0Md'})
#      13 # for index,data in enumerate(div):
#
# C:\anaconda\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# C:\anaconda\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
# ...

# %%
title='유아용품 온라인 시장'
url='https://www.google.com/'
browser.get(url)
element=browser.find_element_by_class_name('gLFyf.gsfi')
element.send_keys(title)
element.submit()
# time.sleep(1)
browser.implicitly_wait(3)
soup=BeautifulSoup(browser.page_source,'html.parser')  
elements=browser.find_elements_by_class_name('LC20lb.DKV0Md')
# elements=browser.find_elements_by_class_name('yuRUbf')
# for c in elements:
#     browser.implicitly_wait(1)
#     c.click()
#     browser.back()
#     browser.implicitly_wait(3)
# soup=BeautifulSoup(browser.page_source,'html.parser')    
# div=soup.find_all('h3',attrs={'class':'yuRUbf'})
# for index,data in enumerate(div):
#     data.click()
#     browser.implicitly_wait(3)
#     browser.back()

# %%
for c in range(0,len(elements)):
    elements[c].click()
    browser.implicitly_wait(3)
    browser.back()
#     time.sleep(2)
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# <ipython-input-63-16803ceef955> in <module>
#       1 for c in range(0,len(elements)):
# ----> 2     elements[c].click()
#       3     browser.implicitly_wait(3)
#       4     browser.back()
#       5 #     time.sleep(2)
#
# C:\anaconda\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# C:\anaconda\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ...

# %%
elements[1]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="85bc8b64e0ce86b9f85f6da09efc7565", element="6b291c4c-bbfa-4e1a-a1ef-aee0cf930360")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="85bc8b64e0ce86b9f85f6da09efc7565", element="f153c649-cb1c-4c6e-be10-a0e20a6fcc6b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="85bc8b64e0ce86b9f85f6da09efc7565", element="3f82114d-889b-45d5-a2ae-87f48d179525")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="85bc8b64e0ce86b9f85f6da09efc7565", element="cfa34de9-e48b-4059-b503-a5ced144c44f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="85bc8b64e0ce86b9f85f6da09efc7565", element="19577603-7840-4063-9972-35fb62b89c2b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="85bc8b64e0ce86b9f85f6da09efc7565", element="7e515974-c613-4fa7-8f9b-5f4c7c83da2b")>,
# ...

# %% [markdown]
# ### 단순 기사 제목만 크롤링하는 경우

# %%
len(elements)
# Out:
# 9

# %%
for e in range(len(elements)):
    element=elements[e].text
    articletitle.append(element)
print(articletitle)
# Out:
# ['4조 육아시장 어떻게 잡나, 육아맘 주 이용 채널 분석하기', '위메프 "유아용품 온라인으로 대량 구매하는 소비자 늘어"', '중국 영유아용품 시장 최신 트렌드 - Kotra 해외시장뉴스', '美 유아용품 온라인쇼핑으로 성장세 지속 - 트렌드 - Kotra 해외 ...', '아이 1명도 안 낳는데…유아용품 산업은 왜 흔들리지 않을까', '점점 커지는 유아용품 시장…신세계 온라인 키즈 전문관 낸다', '세계의 유아용품 온라인 소매 시장(2021-2025년) - 글로벌 ...', '유아용품 온라인 시장 커진다 - 어패럴뉴스', "美 유아용품 시장, '스마트, 프리미엄' 강세-해외시장 뉴스"]

# %%
elements[0].text
# Out:
# '4조 육아시장 어떻게 잡나, 육아맘 주 이용 채널 분석하기'

# %%
articles
# Out:
# ['4조 육아시장 어떻게 잡나, 육아맘 주 이용 채널 분석하기',
#  '본 글은 36개월 이하의 자녀를 둔 엄마 500명, 아빠 200명을 대상으로 조사한 ‘육아 트렌드 리포트 2020’ 내용을 활용해 작성한 글입니다.',
#  '산업연구원이 지난 19년에 발표한 <국내 키즈콘텐츠시장의 현황과 시사점> 보고서에 따르면, 유아용품 시장은 2009년 1조 2,000억 원에서 2015년 약 2조 4,000억 원으로 두 배 가량 성장했으며, 2019년은 4조 원대로 성장했을 것이라 전망했습니다. 국내 출생아 수는 꾸준한 감소세인데 유아용품 시장이 빠르게 성장하는 특별한 이유가 있을까요?',
#  '기사에 따르면 출산율 하락이 오히려 육아시장 성장에 도움을 준다고 분석합니다. 가정 내 아이의 수가 줄어들면서 부모의 지원 쏠림 현상이 나타나고 있습니다. 예전에는 첫째 아이의 옷이나 유아용품을 둘째와 셋째가 물려받아서 쓰곤 했는데, 한 아이만 낳아 키우는 부모가 늘어나면서 더 좋고 더 비싼 프리미엄 유아용품을 사주려는 풍조 덕에 ‘골드키즈’ 시대가 열린 겁니다.',
#  '이에 극심한 저출산 시대인 지금, 육아시장 사로잡기에 대한 관심은 더욱 높아지고 있습니다. 이러한 시장 변화에 맞춰 오픈서베이는 육아 트렌드 리포트를 지난 17년 이후 새롭게 발행했습니다. 육아 트렌드 리포트 2020을 토대로 작성한 본 아티클을 통해 엄마들을 사로잡을 마케팅 전략에 대한 힌트를 얻을 수 있길 바랍니다.',
#  '먼저 엄마들이 자녀 양육 정보를 주로 얻는 채널을 살펴보니, 온라인 커뮤니티를 이용한다는 의견이 가장 많은 것으로 나타났습니다(71.2%). 지난 17년까지 가장 많은 비율을 차지하던 가족·친구 등 육아 선배를 꼽은 엄마들이 적지 않게 줄어든 탓이 큽니다(66.2%, -13.6%P). 이제는 육아 관련 정보도 온라인에서 더욱 많이 얻는 시대가 열린 겁니다.',
# ...

# %%
#rso > div:nth-child(1) > div > div > div.yuRUbf > a > h3
#rso > div:nth-child(2) > div > div > div.yuRUbf > a > h3
